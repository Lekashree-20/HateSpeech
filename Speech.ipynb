# %%
# %%capture
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split

# Text Pre-processing libraries
import nltk
import string
import warnings
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud

# Tensorflow imports to build the model.
import tensorflow as tf
from tensorflow import keras
from keras import layers
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

nltk.download('stopwords')
nltk.download('omw-1.4')
nltk.download('wordnet')
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sb
#       5 from sklearn.model_selection import train_test_split
#       7 # Text Pre-processing libraries
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv("C:/Users/Leka/Downloads/archive (1)/labeled_data.csv")
df.head()
# Out:
#    class                                              tweet
# 0      2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df.shape
# Out:
# (24783, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   24783 non-null  int64
#  1   tweet   24783 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 387.4+ KB

# %%
plt.pie(df['class'].value_counts().values,
        labels = df['class'].value_counts().index,
        autopct='%1.1f%%')
plt.show()

# %%
import string
# Lower case all the words of the tweet before any preprocessing
df['tweet'] = df['tweet'].str.lower()
 
# Removing punctuations present in the text
punctuations_list = string.punctuation
def remove_punctuations(text):
    temp = str.maketrans('', '', punctuations_list)
    return text.translate(temp)
 
df['tweet']= df['tweet'].apply(lambda x: remove_punctuations(x))
df.head()
# Out:
#    class                                              tweet
# 0      2   rt mayasolovely as a woman you shouldnt compl...
# 1      1   rt mleew17 boy dats coldtyga dwn bad for cuff...
# 2      1   rt urkindofbrand dawg rt 80sbaby4life you eve...
# 3      1     rt cganderson vivabased she look like a tranny
# 4      1   rt shenikaroberts the shit you hear about me ...

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Leka\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Leka\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\software\python\lib\site-packages (3.8.1)
# Requirement already satisfied: click in d:\software\python\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\software\python\lib\site-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in d:\software\python\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in d:\software\python\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in c:\users\leka\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
def remove_stopwords(text):
    stop_words = stopwords.words('english')
 
    imp_words = []
 
    # Storing the important words
    for word in str(text).split():
 
        if word not in stop_words:
 
            # Let's Lemmatize the word as well
            # before appending to the imp_words list.
 
            lemmatizer = WordNetLemmatizer()
            lemmatizer.lemmatize(word)
 
            imp_words.append(word)
 
    output = " ".join(imp_words)
 
    return output
df['tweet'] = df['tweet'].apply(lambda text: remove_stopwords(text))
df.head()
# Out:
#    class                                              tweet
# 0      2  rt mayasolovely woman shouldnt complain cleani...
# 1      1  rt mleew17 boy dats coldtyga dwn bad cuffin da...
# 2      1  rt urkindofbrand dawg rt 80sbaby4life ever fuc...
# 3      1           rt cganderson vivabased look like tranny
# 4      1  rt shenikaroberts shit hear might true might f...

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in d:\software\python\lib\site-packages (from wordcloud) (1.26.2)
# Requirement already satisfied: pillow in d:\software\python\lib\site-packages (from wordcloud) (10.1.0)
# Requirement already satisfied: matplotlib in d:\software\python\lib\site-packages (from wordcloud) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\software\python\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\software\python\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\software\python\lib\site-packages (from matplotlib->wordcloud) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\software\python\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\leka\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\software\python\lib\site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\leka\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\leka\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl (301 kB)
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/301.4 kB 435.7 kB/s eta 0:00:01
#    ---------------------------------------  297.0/301.4 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 301.4/301.4 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
def plot_word_cloud(data, typ):
  # Joining all the tweets to get the corpus
  email_corpus = " ".join(data['tweet'])
 
  plt.figure(figsize = (10,10))
   
  # Forming the word cloud
  wc = WordCloud(max_words = 100,
                width = 200,
                height = 100,
                collocations = False).generate(email_corpus)
   
  # Plotting the wordcloud obtained above
  plt.title(f'WordCloud for {typ} emails.', fontsize = 15)
  plt.axis('off')
  plt.imshow(wc)
  plt.show()
  print()
plot_word_cloud(df[df['class']==2], typ='Neither')

# %%
class_2 = df[df['class'] == 2]
class_1 = df[df['class'] == 1].sample(n=3500)
class_0 = df[df['class'] == 0]
 
balanced_df = pd.concat([class_0, class_0, class_0, class_1, class_2], axis=0)

# %%
plt.pie(balanced_df['class'].value_counts().values,
        labels=balanced_df['class'].value_counts().index,
        autopct='%1.1f%%')
plt.show()

# %%
from sklearn.model_selection import train_test_split
features = balanced_df['tweet']
target = balanced_df['class']
 
X_train, X_val, Y_train, Y_val = train_test_split(features,
                                                  target,
                                                  test_size=0.2,
                                                  random_state=22)
X_train.shape, X_val.shape
# Out:
# ((9562,), (2391,))

# %%
Y_train = Y_train.values.reshape(-1, 1)  # Reshape for compatibility
Y_val = Y_val.values.reshape(-1, 1)
Y_train.shape, Y_val.shape
# Out:
# ((9562, 1), (2391, 1))

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.16.1-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Collecting tensorflow-intel==2.16.1 (from tensorflow)
#   Downloading tensorflow_intel-2.16.1-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading h5py-3.11.0-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading ml_dtypes-0.3.2-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging in c:\users\leka\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\software\python\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.2)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\software\python\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in d:\software\python\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\leka\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\software\python\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\software\python\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\software\python\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.60.1)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading keras-3.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in d:\software\python\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.2)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow)
#   Downloading wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: rich in d:\software\python\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.0)
# Collecting namex (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow)
#   Downloading optree-0.11.0-cp312-cp312-win_amd64.whl.metadata (46 kB)
#      ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#      ---------------------------------------- 46.2/46.2 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software\python\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\software\python\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software\python\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software\python\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Collecting markdown>=2.6.8 (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow)
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow)
#   Downloading werkzeug-3.0.2-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\software\python\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\software\python\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\leka\appdata\roaming\python\python312\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in d:\software\python\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Downloading tensorflow-2.16.1-cp312-cp312-win_amd64.whl (2.1 kB)
# Downloading tensorflow_intel-2.16.1-cp312-cp312-win_amd64.whl (377.1 MB)
#    ---------------------------------------- 0.0/377.1 MB ? eta -:--:--
#    ---------------------------------------- 0.5/377.1 MB 16.2 MB/s eta 0:00:24
#    ---------------------------------------- 1.2/377.1 MB 15.1 MB/s eta 0:00:25
#    ---------------------------------------- 1.5/377.1 MB 12.0 MB/s eta 0:00:32
#    ---------------------------------------- 2.0/377.1 MB 11.4 MB/s eta 0:00:33
#    ---------------------------------------- 2.3/377.1 MB 10.5 MB/s eta 0:00:36
#    ---------------------------------------- 2.6/377.1 MB 9.8 MB/s eta 0:00:39
#    ---------------------------------------- 3.5/377.1 MB 11.1 MB/s eta 0:00:34
#    ---------------------------------------- 4.4/377.1 MB 12.3 MB/s eta 0:00:31
#     --------------------------------------- 5.6/377.1 MB 13.8 MB/s eta 0:00:27
#     --------------------------------------- 6.3/377.1 MB 13.9 MB/s eta 0:00:27
#     --------------------------------------- 6.9/377.1 MB 13.7 MB/s eta 0:00:28
#     --------------------------------------- 7.4/377.1 MB 13.6 MB/s eta 0:00:28
#     --------------------------------------- 8.0/377.1 MB 13.4 MB/s eta 0:00:28
#     --------------------------------------- 8.5/377.1 MB 13.3 MB/s eta 0:00:28
#     --------------------------------------- 9.1/377.1 MB 13.2 MB/s eta 0:00:28
#    - -------------------------------------- 9.6/377.1 MB 13.1 MB/s eta 0:00:29
#    - -------------------------------------- 10.1/377.1 MB 13.0 MB/s eta 0:00:29
#    - -------------------------------------- 10.7/377.1 MB 12.8 MB/s eta 0:00:29
#    - -------------------------------------- 11.3/377.1 MB 12.8 MB/s eta 0:00:29
#    - -------------------------------------- 11.8/377.1 MB 12.8 MB/s eta 0:00:29
#    - -------------------------------------- 12.4/377.1 MB 13.1 MB/s eta 0:00:28
#    - -------------------------------------- 12.9/377.1 MB 13.6 MB/s eta 0:00:27
#    - -------------------------------------- 13.5/377.1 MB 13.1 MB/s eta 0:00:28
#    - -------------------------------------- 14.0/377.1 MB 13.1 MB/s eta 0:00:28
#    - -------------------------------------- 14.6/377.1 MB 12.6 MB/s eta 0:00:29
#    - -------------------------------------- 15.1/377.1 MB 12.4 MB/s eta 0:00:30
#    - -------------------------------------- 15.7/377.1 MB 11.9 MB/s eta 0:00:31
#    - -------------------------------------- 16.2/377.1 MB 11.7 MB/s eta 0:00:31
#    - -------------------------------------- 16.8/377.1 MB 11.7 MB/s eta 0:00:31
#    - -------------------------------------- 17.3/377.1 MB 11.9 MB/s eta 0:00:31
#    - -------------------------------------- 17.8/377.1 MB 11.7 MB/s eta 0:00:31
#    - -------------------------------------- 18.4/377.1 MB 11.9 MB/s eta 0:00:31
#    - -------------------------------------- 18.5/377.1 MB 11.9 MB/s eta 0:00:31
#    -- ------------------------------------- 19.5/377.1 MB 11.9 MB/s eta 0:00:31
#    -- ------------------------------------- 20.0/377.1 MB 11.9 MB/s eta 0:00:30
#    -- ------------------------------------- 20.7/377.1 MB 11.7 MB/s eta 0:00:31
#    -- ------------------------------------- 21.1/377.1 MB 11.9 MB/s eta 0:00:30
#    -- ------------------------------------- 21.7/377.1 MB 11.9 MB/s eta 0:00:30
#    -- ------------------------------------- 22.2/377.1 MB 11.7 MB/s eta 0:00:31
#    -- ------------------------------------- 22.8/377.1 MB 11.7 MB/s eta 0:00:31
#    -- ------------------------------------- 23.3/377.1 MB 11.7 MB/s eta 0:00:31
#    -- ------------------------------------- 23.8/377.1 MB 11.7 MB/s eta 0:00:31
#    -- ------------------------------------- 24.3/377.1 MB 11.7 MB/s eta 0:00:31
#    -- ------------------------------------- 24.8/377.1 MB 11.7 MB/s eta 0:00:31
#    -- ------------------------------------- 25.4/377.1 MB 11.7 MB/s eta 0:00:31
#    -- -------------------------------------
MB 11.7 MB/s eta 0:00:24
#    ---------- ---------------------------- 103.9/377.1 MB 11.5 MB/s eta 0:00:24
#    ---------- ---------------------------- 104.3/377.1 MB 11.3 MB/s eta 0:00:25
#    ---------- ---------------------------- 104.6/377.1 MB 10.9 MB/s eta 0:00:25
#    ---------- ---------------------------- 104.9/377.1 MB 10.9 MB/s eta 0:00:25
#    ---------- ---------------------------- 105.2/377.1 MB 10.6 MB/s eta 0:00:26
#    ---------- ---------------------------- 105.6/377.1 MB 10.4 MB/s eta 0:00:27
#    ---------- ---------------------------- 106.0/377.1 MB 10.2 MB/s eta 0:00:27
#    ---------- ---------------------------- 106.3/377.1 MB 10.1 MB/s eta 0:00:27
#    ----------- ---------------------------- 106.6/377.1 MB 9.9 MB/s eta 0:00:28
#    ----------- ---------------------------- 107.0/377.1 MB 9.9 MB/s eta 0:00:28
#    ----------- ---------------------------- 107.3/377.1 MB 9.5 MB/s eta 0:00:29
#    ----------- ---------------------------- 107.7/377.1 MB 9.4 MB/s eta 0:00:29
#    ----------- ---------------------------- 108.0/377.1 MB 9.4 MB/s eta 0:00:29
#    ----------- ---------------------------- 108.3/377.1 MB 9.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 108.7/377.1 MB 9.1 MB/s eta 0:00:30
#    ----------- ---------------------------- 109.1/377.1 MB 9.0 MB/s eta 0:00:30
#    ----------- ---------------------------- 109.4/377.1 MB 8.8 MB/s eta 0:00:31
#    ----------- ---------------------------- 109.8/377.1 MB 8.7 MB/s eta 0:00:31
#    ----------- ---------------------------- 110.2/377.1 MB 8.6 MB/s eta 0:00:31
#    ----------- ---------------------------- 110.6/377.1 MB 8.5 MB/s eta 0:00:32
#    ----------- ---------------------------- 110.9/377.1 MB 8.4 MB/s eta 0:00:32
#    ----------- ---------------------------- 111.3/377.1 MB 8.3 MB/s eta 0:00:33
#    ----------- ---------------------------- 111.6/377.1 MB 8.2 MB/s eta 0:00:33
#    ----------- ---------------------------- 111.9/377.1 MB 8.0 MB/s eta 0:00:34
#    ----------- ---------------------------- 112.4/377.1 MB 8.0 MB/s eta 0:00:34
#    ----------- ---------------------------- 112.9/377.1 MB 8.0 MB/s eta 0:00:34
#    ------------ --------------------------- 113.5/377.1 MB 8.0 MB/s eta 0:00:34
#    ------------ --------------------------- 114.0/377.1 MB 8.0 MB/s eta 0:00:33
#    ------------ --------------------------- 114.5/377.1 MB 8.1 MB/s eta 0:00:33
#    ------------ --------------------------- 115.0/377.1 MB 8.4 MB/s eta 0:00:32
#    ------------ --------------------------- 115.6/377.1 MB 8.6 MB/s eta 0:00:31
#    ------------ --------------------------- 116.1/377.1 MB 8.7 MB/s eta 0:00:30
#    ------------ --------------------------- 116.7/377.1 MB 9.0 MB/s eta 0:00:30
#    ------------ --------------------------- 117.2/377.1 MB 9.1 MB/s eta 0:00:29
#    ------------ --------------------------- 117.8/377.1 MB 9.5 MB/s eta 0:00:28
#    ------------ --------------------------- 118.3/377.1 MB 9.6 MB/s eta 0:00:27
#    ------------ --------------------------- 118.9/377.1 MB 9.9 MB/s eta 0:00:27
#    ------------ -------------------------- 119.4/377.1 MB 10.1 MB/s eta 0:00:26
#    ------------ -------------------------- 120.0/377.1 MB 10.4 MB/s eta 0:00:25
#    ------------ -------------------------- 120.5/377.1 MB 10.6 MB/s eta 0:00:25
#    ------------ -------------------------- 121.1/377.1 MB 10.9 MB/s eta 0:00:24
#    ------------ -------------------------- 121.6/377.1 MB 11.1 MB/s eta 0:00:24
#    ------------ -------------------------- 122.2/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------ -------------------------- 122.7/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------ -------------------------- 123.2/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------ -------------------------- 123.8/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------ -------------------------- 124.3/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------ -------------------------- 124.9/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------ -------------------------- 125.4/377.1 MB 11.9 MB/s eta 0:00:22
#    ------------- ------------------------- 126.0/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------- ------------------------- 126.5/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------- ------------------------- 127.1/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------- ------------------------- 127.6/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------- ------------------------- 128.2/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------- ------------------------- 128.7/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------- ------------------------- 129.3/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------- ------------------------- 129.9/377.1 MB 11.9 MB/s eta 0:00:21
#    ------------- ------------------------- 130.4/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------- ------------------------- 130.9/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------- ------------------------- 131.5/377.1 MB 11.7 MB/s eta 0:00:22
#    ------------- ------------------------- 132.0/377.1 MB 11.7 MB/s eta 0:00:21
#    ------------- ------------------------- 132.6/377.1 MB 11.7 MB/s eta 0:00:21
#    ------------- ------------------------- 133.1/377.1 MB 11.7 MB/s eta 0:00:21
#    ------------- ------------------------- 133.7/377.1 MB 11.7 MB/s eta 0:00:21
#    ------------- ------------------------- 134.2/377.1 MB 11.7 MB/s eta 0:00:21
#    ------------- ------------------------- 134.8/377.1 MB 11.7 MB/s eta 0:00:21
#    ------------- ------------------------- 135.3/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 135.9/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 136.4/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 136.9/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 137.5/377.1 MB 11.9 MB/s eta 0:00:21
#    -------------- ------------------------ 138.1/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 138.6/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 139.1/377.1 MB 11.9 MB/s eta 0:00:20
#    -------------- ------------------------ 139.7/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 140.3/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 140.8/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 141.4/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 141.9/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------ 142.4/377.1 MB 11.7 MB/s eta 0:00:21
#    -------------- ------------------------
5 MB/s eta 0:00:02
#    ----- ---------------------------------- 3.9/26.4 MB 17.5 MB/s eta 0:00:02
#    ------ --------------------------------- 4.4/26.4 MB 16.5 MB/s eta 0:00:02
#    ------- -------------------------------- 4.9/26.4 MB 15.7 MB/s eta 0:00:02
#    -------- ------------------------------- 5.5/26.4 MB 15.2 MB/s eta 0:00:02
#    --------- ------------------------------ 6.0/26.4 MB 14.8 MB/s eta 0:00:02
#    --------- ------------------------------ 6.6/26.4 MB 14.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.7/26.4 MB 14.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.7/26.4 MB 14.0 MB/s eta 0:00:02
#    ------------ --------------------------- 8.2/26.4 MB 13.8 MB/s eta 0:00:02
#    ------------- -------------------------- 8.8/26.4 MB 13.7 MB/s eta 0:00:02
#    -------------- ------------------------- 9.3/26.4 MB 13.5 MB/s eta 0:00:02
#    -------------- ------------------------- 9.9/26.4 MB 13.4 MB/s eta 0:00:02
#    --------------- ------------------------ 10.4/26.4 MB 13.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 11.0/26.4 MB 12.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 11.5/26.4 MB 12.6 MB/s eta 0:00:02
#    ------------------ --------------------- 12.1/26.4 MB 12.6 MB/s eta 0:00:02
#    ------------------- -------------------- 12.6/26.4 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 13.2/26.4 MB 12.4 MB/s eta 0:00:02
#    -------------------- ------------------- 13.7/26.4 MB 11.9 MB/s eta 0:00:02
#    --------------------- ------------------ 14.3/26.4 MB 11.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 14.8/26.4 MB 11.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 15.3/26.4 MB 11.7 MB/s eta 0:00:01
#    ------------------------ --------------- 15.9/26.4 MB 11.7 MB/s eta 0:00:01
#    ------------------------ --------------- 16.4/26.4 MB 11.7 MB/s eta 0:00:01
#    ------------------------- -------------- 16.9/26.4 MB 11.7 MB/s eta 0:00:01
#    -------------------------- ------------- 17.5/26.4 MB 11.9 MB/s eta 0:00:01
#    --------------------------- ------------ 18.0/26.4 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 18.5/26.4 MB 11.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 19.0/26.4 MB 11.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 19.6/26.4 MB 11.5 MB/s eta 0:00:01
#    ------------------------------ --------- 20.1/26.4 MB 11.5 MB/s eta 0:00:01
#    ------------------------------- -------- 20.6/26.4 MB 11.5 MB/s eta 0:00:01
#    -------------------------------- ------- 21.2/26.4 MB 11.5 MB/s eta 0:00:01
#    -------------------------------- ------- 21.7/26.4 MB 11.5 MB/s eta 0:00:01
#    --------------------------------- ------ 22.3/26.4 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.8/26.4 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.3/26.4 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 23.9/26.4 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 24.4/26.4 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------- -- 24.9/26.4 MB 11.3 MB/s eta 0:00:01
#    -------------------------------------- - 25.5/26.4 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  26.0/26.4 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  26.4/26.4 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  26.4/26.4 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  26.4/26.4 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 9.9 MB/s eta 0:00:00
# Downloading ml_dtypes-0.3.2-cp312-cp312-win_amd64.whl (128 kB)
#    ---------------------------------------- 0.0/128.6 kB ? eta -:--:--
#    ---------------------------------------- 128.6/128.6 kB 7.9 MB/s eta 0:00:00
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ---------------------------------------- 0.0/65.5 kB ? eta -:--:--
#    ---------------------------------------- 65.5/65.5 kB ? eta 0:00:00
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.9/5.5 MB 29.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.6/5.5 MB 20.2 MB/s eta 0:00:01
#    -------------- ------------------------- 2.0/5.5 MB 16.2 MB/s eta 0:00:01
#    ------------------- -------------------- 2.7/5.5 MB 15.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.3/5.5 MB 15.1 MB/s eta 0:00:01
#    --------------------------- ------------ 3.8/5.5 MB 14.3 MB/s eta 0:00:01
#    ------------------------------- -------- 4.3/5.5 MB 13.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.8/5.5 MB 13.4 MB/s eta 0:00:01
#    -------------------------------------- - 5.3/5.5 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 12.5 MB/s eta 0:00:00
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ---------------------------------------- 0.0/105.4 kB ? eta -:--:--
#    ---------------------------------------- 105.4/105.4 kB ? eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.0.2-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.8 kB ? eta -:--:--
#    ---------------------------------------- 226.8/226.8 kB 6.8 MB/s eta 0:00:00
# Downloading wheel-0.43.0-py3-none-any.whl (65 kB)
#    ---------------------------------------- 0.0/65.8 kB ? eta -:--:--
#    ---------------------------------------- 65.8/65.8 kB 3.5 MB/s eta 0:00:00
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.11.0-cp312-cp312-win_amd64.whl (241 kB)
#    ---------------------------------------- 0.0/241.7 kB ? eta -:--:--
#    ---------------------------------------- 241.7/241.7 kB ? eta 0:00:00
# Installing collected packages: namex, libclang, flatbuffers, wheel, werkzeug, termcolor, tensorboard-data-server, optree, opt-einsum, ml-dtypes, markdown, h5py, google-pasta, gast, absl-py, tensorboard, astunparse, keras, tensorflow-intel, tensorflow
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.5.4 google-pasta-0.2.0 h5py-3.11.0 keras-3.2.1 libclang-18.1.1 markdown-3.6 ml-dtypes-0.3.2 namex-0.0.8 opt-einsum-3.3.0 optree-0.11.0 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 tensorflow-intel-2.16.1 termcolor-2.4.0 werkzeug-3.0.2 wheel-0.43.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
max_words = 5000
max_len = 100
 
token = Tokenizer(num_words=max_words,
                  lower=True,
                  split=' ')
 
token.fit_on_texts(X_train)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# training the tokenizer
max_words = 5000
token = Tokenizer(num_words=max_words,
                  lower=True,
                  split=' ')
token.fit_on_texts(X_train)
 
#Generating token embeddings
Training_seq = token.texts_to_sequences(X_train)
Training_pad = pad_sequences(Training_seq,
                             maxlen=50,
                             padding='post',
                             truncating='post')
 
Testing_seq = token.texts_to_sequences(X_val)
Testing_pad = pad_sequences(Testing_seq,
                            maxlen=50,
                            padding='post',
                            truncating='post')

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in d:\software\python\lib\site-packages (3.2.1)
# Requirement already satisfied: absl-py in d:\software\python\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in d:\software\python\lib\site-packages (from keras) (1.26.2)
# Requirement already satisfied: rich in d:\software\python\lib\site-packages (from keras) (13.7.0)
# Requirement already satisfied: namex in d:\software\python\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in d:\software\python\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in d:\software\python\lib\site-packages (from keras) (0.11.0)
# Requirement already satisfied: ml-dtypes in d:\software\python\lib\site-packages (from keras) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\software\python\lib\site-packages (from optree->keras) (4.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\software\python\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\leka\appdata\roaming\python\python312\site-packages (from rich->keras) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in d:\software\python\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
model = keras.models.Sequential([
    layers.Embedding(max_words, 32, input_length=max_len),
    layers.Bidirectional(layers.LSTM(16)),
    layers.Dense(512, activation='relu', kernel_regularizer='l1'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(3, activation='softmax')
])
 
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
 
model.summary()
# Out:
# d:\Software\Python\Lib\site-packages\keras\src\layers\core\embedding.py:86: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.build(input_shape=(None, max_len))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 32)        │       160,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 32)             │         6,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │         1,539 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 186,755 (729.51 KB)
#  Trainable params: 185,731 (725.51 KB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-2.0.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: pyparsing>=3 in d:\software\python\lib\site-packages (from pydot) (3.1.1)
# Downloading pydot-2.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: pydot
# Successfully installed pydot-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
keras.utils.plot_model(
    model,
    show_shapes=True,
    show_dtype=True,
    show_layer_activations=True
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File d:\Software\Python\Lib\site-packages\pydot\core.py:1753, in Dot.create(self, prog, format, encoding)
#    1752 try:
# -> 1753     stdout_data, stderr_data, process = call_graphviz(
#    1754         program=prog,
#    1755         arguments=arguments,
#    1756         working_dir=tmp_dir,
#    1757     )
#    1758 except OSError as e:
#
# File d:\Software\Python\Lib\site-packages\pydot\core.py:133, in call_graphviz(program, arguments, working_dir, **kwargs)
#     131 program_with_args = [program] + arguments
# --> 133 process = subprocess.Popen(
#     134     program_with_args,
#     135     env=env,
#     136     cwd=working_dir,
#     137     shell=False,
#     138     stderr=subprocess.PIPE,
#     139     stdout=subprocess.PIPE,
#     140     **kwargs,
#     141 )
#     142 stdout_data, stderr_data = process.communicate()
#
# File d:\Software\Python\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File d:\Software\Python\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File d:\Software\Python\Lib\site-packages\keras\src\utils\model_visualization.py:37, in check_graphviz()
#      34 try:
#      35     # Attempt to create an image of a blank graph
#      36     # to check the pydot/graphviz installation.
# ---> 37     pydot.Dot.create(pydot.Dot())
#      38     return True
#
# File d:\Software\Python\Lib\site-packages\pydot\core.py:1762, in Dot.create(self, prog, format, encoding)
#    1761     args[1] = '"{prog}" not found in path.'.format(prog=prog)
# -> 1762     raise OSError(*args)
#    1763 else:
#
# FileNotFoundError: [WinError 2] "dot" not found in path.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 keras.utils.plot_model(
#       2     model,
#       3     show_shapes=True,
#       4     show_dtype=True,
#       5     show_layer_activations=True
#       6 )
#
# File d:\Software\Python\Lib\site-packages\keras\src\utils\model_visualization.py:406, in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, show_layer_activations, show_trainable, **kwargs)
#     404     else:
#     405         raise ImportError(message)
# --> 406 if not check_graphviz():
#     407     message = (
#     408         "You must install graphviz "
#     409         "(see instructions at https://graphviz.gitlab.io/download/) "
#     410         "for `plot_model` to work."
#     411     )
#     412     if "IPython.core.magics.namespace" in sys.modules:
#     413         # We don't raise an exception here in order to avoid crashing
#     414         # notebook tests where graphviz is not available.
#
# File d:\Software\Python\Lib\site-packages\keras\src\utils\model_visualization.py:39, in check_graphviz()
#      37     pydot.Dot.create(pydot.Dot())
#      38     return True
# ---> 39 except (OSError, pydot.InvocationException):
#      40     return False
#
# AttributeError: module 'pydot' has no attribute 'InvocationException'

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
 
es = EarlyStopping(patience=3,
                   monitor = 'val_accuracy',
                   restore_best_weights = True)
 
lr = ReduceLROnPlateau(patience = 2,
                       monitor = 'val_loss',
                       factor = 0.5,
                       verbose = 0)

# %%
history = model.fit(X_train, Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=50,
                    verbose=1,
                    batch_size=32,
                    callbacks=[lr, es])
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 history = model.fit(X_train, Y_train,
#       2                     validation_data=(X_val, Y_val),
#       3                     epochs=50,
#       4                     verbose=1,
#       5                     batch_size=32,
#       6                     callbacks=[lr, es])
#
# File d:\Software\Python\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File d:\Software\Python\Lib\site-packages\keras\src\backend\tensorflow\nn.py:579, in categorical_crossentropy(target, output, from_logits, axis)
#     577 for e1, e2 in zip(target.shape, output.shape):
#     578     if e1 is not None and e2 is not None and e1 != e2:
# --> 579         raise ValueError(
#     580             "Arguments `target` and `output` must have the same shape. "
#     581             "Received: "
#     582             f"target.shape={target.shape}, output.shape={output.shape}"
#     583         )
#     585 output, from_logits = _get_logits(
#     586     output, from_logits, "Softmax", "categorical_crossentropy"
#     587 )
#     588 if from_logits:
#
# ValueError: Arguments `target` and `output` must have the same shape. Received: target.shape=(None, 1), output.shape=(None, 3)
